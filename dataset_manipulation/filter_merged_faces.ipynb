# %%
import pandas as pd

from PIL import Image

from tqdm import tqdm

# %%
df = pd.read_csv('../data/merged_faces.csv')
df['cords'] = df['cords'].apply(lambda x: eval(x))

# %%
df.columns
# Out:
# Index(['img_id', 'difference', 'cords'], dtype='object')

# %%
df['difference'].hist(bins=50)
# Out:
# <Axes: >

# %%
df['x'] = df['cords'].apply(lambda x: x[2]) # equals to both width and height

# %%
df['x'].describe()
# Out:
# count    33331.000000
# mean       139.173262
# std         67.931663
# min         20.000000
# 25%         83.000000
# 50%        127.000000
# 75%        188.000000
# max        362.000000
# Name: x, dtype: float64

# %%
df['x'].hist(bins=50)
# Out:
# <Axes: >

# %%
(df['x']>=80).sum()/len(df)*100
# Out:
# 76.33134319402359

# %%
df[df['x']>=80].to_csv('../data/merged_faces_filtered_by_size.csv', index=False)
