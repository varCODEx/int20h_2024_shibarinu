# %%
import cv2
import mediapipe
import numpy as np
import pandas as pd
import glob
import os
import tqdm
import matplotlib.pyplot as plt

# %%
img = cv2.imread('cut_faces/14689328_1984-11-25_2009.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img2 = cv2.imread('cut_faces/13821502_1987-11-14_2008.jpg')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(16,12))
plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img2)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x229d61b08e0>)

# %%
img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
img2 = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)

plt.figure(figsize=(16,12))
plt.subplot(121), plt.imshow(img, cmap='gray')
plt.subplot(122), plt.imshow(img2, cmap='gray')
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x229d9dc2220>)

# %%
img = cv2.equalizeHist(img)
img2 = cv2.equalizeHist(img2)

plt.figure(figsize=(16,12))
plt.subplot(121), plt.imshow(img, cmap='gray')
plt.subplot(122), plt.imshow(img2, cmap='gray')
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x229d9eaa910>)
